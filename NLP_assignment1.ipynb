# %% [markdown]
# # Assignment 1: Word Clouds & N -grams
#
# Name: Aditya Raj Sinha
#
# Roll No.: 2301201189

# %%
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt')

try:
    nltk.data.find('tokenizers/punkt_tab')
except LookupError:
    nltk.download('punkt_tab')


words = word_tokenize(text)
print(words[:10])
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['Natural', 'language', 'processing', '(', 'NLP', ')', 'is', 'a', 'subfield', 'of']

# %%
from nltk.corpus import stopwords

try:
    nltk.data.find('corpora/stopwords')
except LookupError:
    nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

non_stop_words = [word for word in words if word.lower() not in stop_words]

print(non_stop_words[:10])
# Out:
# ['Natural', 'language', 'processing', '(', 'NLP', ')', 'subfield', 'linguistics', ',', 'computer']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text_for_wordcloud = " ".join(non_stop_words)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_for_wordcloud)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from nltk.util import ngrams

bigrams = list(ngrams(words, n=2))
trigrams = list(ngrams(words, n=3))

print("First 10 Bigrams:")
print(bigrams[:10])
print("\nFirst 10 Trigrams:")
print(trigrams[:10])
# Out:
# First 10 Bigrams:
# [('Natural', 'language'), ('language', 'processing'), ('processing', '('), ('(', 'NLP'), ('NLP', ')'), (')', 'is'), ('is', 'a'), ('a', 'subfield'), ('subfield', 'of'), ('of', 'linguistics')]
#
# First 10 Trigrams:
# [('Natural', 'language', 'processing'), ('language', 'processing', '('), ('processing', '(', 'NLP'), ('(', 'NLP', ')'), ('NLP', ')', 'is'), (')', 'is', 'a'), ('is', 'a', 'subfield'), ('a', 'subfield', 'of'), ('subfield', 'of', 'linguistics'), ('of', 'linguistics', ',')]
